# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

# %%
property_data = pd.read_csv("data/nsw_property_data_2019-09-10.csv")
property_data.shape
# Out:
# (57680, 10)

# %%
property_data.head()
# Out:
#                                                 link  \
# 0  https://www.realestate.com.au/property-apartme...
# 1  https://www.realestate.com.au/property-apartme...
# 2  https://www.realestate.com.au/property-apartme...
# 3  https://www.realestate.com.au/property-apartme...
# 4  https://www.realestate.com.au/property-apartme...
#
#                              address  postcode                         price  \
# 0         511/188 Day Street, Sydney      2000  For Sale | Obsidian Property
# 1  1803/178 Thomas Street, Haymarket      2000                 Contact Agent
# 2       2406/168 Kent Street, Sydney      2000                    $1,540,000
# 3        806/1 Hosking Place, Sydney      2000                      $719,000
# 4  1702/11-15 Alberta Street, Sydney      2000                       Auction
#
#   num_beds num_baths num_cars property_area land_area property_type
# 0        3         2        1          None      None     Apartment
# 1        2         2        2          None      None     Apartment
# 2        1         1        1          None      None     Apartment
# 3        1         1     None          None      None     Apartment
# 4        2         2        1          None      None     Apartment

# %% [markdown]
# Strip whitespace from number of bed/bath/car and convert to integer

# %%
for col in ['num_beds','num_baths','num_cars']:
    property_data[col] = np.where(property_data[col]=='None',0,property_data[col]).astype(int)

# %% [markdown]
# Convert price to a numeric if it exists

# %%
property_data['price_strip'] = (property_data['price'].apply(lambda x: x.replace('$','')) 
    .apply(lambda x: x.replace(',','')).apply(lambda x: x.replace(r'[a-zA-Z]','')))

property_data['price_numeric'] = pd.to_numeric(property_data['price_strip'], errors='coerce')

# %%
print("% of all listings which have unknown price: ",round(100*property_data['price_numeric'].isnull().sum()/len(property_data),2))
# Out:
# % of all listings which have unknown price:  48.07

# %% [markdown]
# Create flag for Auction if price contains 'Auction'

# %%
property_data['auction'] = np.where(property_data.price.str.lower().str.contains('auction'),True,False)

# %% [markdown]
# Property area and land area to numeric

# %%
for col in ['property_area','land_area']:
    property_data[col] = property_data[col].apply(lambda x: x.strip())
    property_data[col+'_num'] = pd.to_numeric(property_data[col], errors='coerce')

# %% [markdown]
# Join the latitude and longitudes to the postcode (we could get even more exact lat/longs from a geocoding service)

# %%
# Get Postcodes
postcodes = pd.read_csv("./data/australian_postcodes.csv")
postcode_mapping = postcodes[(postcodes.type=="Delivery Area") & (postcodes.long != postcodes.lat)]

# We just need 1 row per postcode
postcode_mapping= postcode_mapping[['postcode','lat','long']].drop_duplicates()

# %%
property_data_postcode = property_data.merge(right=postcode_mapping, how='left', on='postcode')

# %%
property_data_postcode.shape
# Out:
# (57680, 17)

# %%
property_data
# Out:
#                                                     link  \
# 0      https://www.realestate.com.au/property-apartme...
# 1      https://www.realestate.com.au/property-apartme...
# 2      https://www.realestate.com.au/property-apartme...
# 3      https://www.realestate.com.au/property-apartme...
# 4      https://www.realestate.com.au/property-apartme...
# ...                                                  ...
# 57675  https://www.realestate.com.au/property-townhou...
# 57676  https://www.realestate.com.au/property-townhou...
# 57677  https://www.realestate.com.au/property-house-a...
# 57678  https://www.realestate.com.au/property-residen...
# 57679  https://www.realestate.com.au/property-other-a...
#
#                                        address  postcode  \
# 0                   511/188 Day Street, Sydney      2000
# 1            1803/178 Thomas Street, Haymarket      2000
# 2                 2406/168 Kent Street, Sydney      2000
# 3                  806/1 Hosking Place, Sydney      2000
# 4            1702/11-15 Alberta Street, Sydney      2000
# ...                                        ...       ...
# 57675  Address available on request, Moncrieff      2914
# 57676  Address available on request, Moncrieff      2914
# 57677  Address available on request, Moncrieff      2914
# 57678             11/1 Jack Ryan Street, Forde      2914
# 57679      77 Bernard Heinze Avenue, Moncrieff      2914
#
#                               price  num_beds  num_baths  num_cars  \
# 0      For Sale | Obsidian Property         3          2         1
# 1                     Contact Agent         2          2         2
# 2                        $1,540,000         1          1         1
# 3                          $719,000         1          1         0
# 4                           Auction         2          2         1
# ...                             ...       ...        ...       ...
# 57675                      $440,000         2          2         1
# 57676                      $465,000         3          2         1
# 57677         Offers Above $350,000         3          2         2
# 57678                       Auction         0          0         0
# 57679                      $510,000         3          2         2
#
#       property_area land_area     property_type                   price_strip  \
# 0              None      None         Apartment  For Sale | Obsidian Property
# 1              None      None         Apartment                 Contact Agent
# 2              None      None         Apartment                       1540000
# 3              None      None         Apartment                        719000
# 4              None      None         Apartment                       Auction
# ...             ...       ...               ...                           ...
# 57675           100      None         Townhouse                        440000
# 57676           107      None         Townhouse                        465000
# 57677          None      None             House           Offers Above 350000
# 57678          None      0.58  Residential Land                       Auction
# 57679          None      None             Other                        510000
#
#        price_numeric  auction  property_area_num  land_area_num
# 0                NaN    False                NaN            NaN
# 1                NaN    False                NaN            NaN
# 2          1540000.0    False                NaN            NaN
# 3           719000.0    False                NaN            NaN
# 4                NaN     True                NaN            NaN
# ...              ...      ...                ...            ...
# 57675       440000.0    False              100.0            NaN
# 57676       465000.0    False              107.0            NaN
# 57677            NaN    False                NaN            NaN
# 57678            NaN     True                NaN           0.58
# 57679       510000.0    False                NaN            NaN
#
# [57680 rows x 15 columns]

# %%
property_data_postcode.to_csv('data/property_data_cleaned_21092019.csv')
